# %%
import pandas as pd
from report_to_dossier import resolve_dataframe

df = pd.read_excel("/home/rb/Documents/Code/Rekenkamer/_DATA/rekenkamer.xlsx")
df = resolve_dataframe(df, title_col="title", sleep_s=0.5)
# Out:
# Resolving 1557 unique titles...
#   10/1557
#   20/1557
#   30/1557
#   40/1557
#   50/1557
#   60/1557
#   70/1557
#   80/1557
#   90/1557
#   100/1557
#   110/1557
#   120/1557
#   130/1557
#   140/1557
#   150/1557
#   160/1557
#   170/1557
#   180/1557
#   190/1557
#   200/1557
#   210/1557
#   220/1557
#   230/1557
#   240/1557
#   250/1557
#   260/1557
#   270/1557
#   280/1557
#   290/1557
#   300/1557
#   310/1557
#   320/1557
#   330/1557
#   340/1557
#   350/1557
#   360/1557
#   370/1557
#   380/1557
#   390/1557
#   400/1557
#   410/1557
#   420/1557
#   430/1557
#   440/1557
#   450/1557
#   460/1557
#   470/1557
#   480/1557
#   490/1557
#   500/1557
#   510/1557
#   520/1557
#   530/1557
#   540/1557
#   550/1557
#   560/1557
#   570/1557
#   580/1557
#   590/1557
#   600/1557
#   610/1557
#   620/1557
#   630/1557
#   640/1557
#   650/1557
#   660/1557
#   670/1557
#   680/1557
#   690/1557
#   700/1557
#   710/1557
#   720/1557
#   730/1557
#   740/1557
#   750/1557
# ...

# %%
df.dossier_resolved.value_counts()
# Out:
# dossier_resolved
# 31865      13
# 21501      13
# 26643       8
# 29628       7
# 35420       6
#            ..
# 27045       1
# 25970       1
# 27458       1
# 31031-X     1
# 32637       1
# Name: count, Length: 439, dtype: int64

# %%
# Inspect results
print(df["dossier_confidence"].value_counts())
print(df[df["dossier_confidence"] == "low"][["title", "dossier_resolved", "dossier_n_total"]])
# Out:
# dossier_confidence
# none      1002
# high       284
# medium     264
# low         70
# Name: count, dtype: int64
#                                                   title dossier_resolved  \
# 8     Beantwoording Kamervragen over het rapport Mon...            32014
# 10    Beantwoording Kamervragen over het Rapport bij...          33240-X
# 11    Beantwoording Kamervragen over het Rapport bij...        33240-III
# 32    Aandachtpunten bij de begroting 2013 van de mi...            31865
# 36    Aandachtpunten bij de begroting 2013 van de mi...            31865
# ...                                                 ...              ...
# 1540  Resultaten verantwoordingsonderzoek 2023 Minis...       36560-XIII
# 1570                                  Beleidsevaluaties            32637
# 1581                  Onderzoek naar uitvoeringstoetsen            36263
# 1598                                 Uitvoeringstoetsen            29247
# ...
